# %%
import pandas as pd
import csv 

data = pd.read_csv('/Users/aginni/Documents/USDA_SR/NUTR_DEF.txt',sep = '^',header = None,engine = 'python')
# print(data)
data.replace('^',',')
# data.replace('~',"")
data.columns = ['Nutrient_no','Units','tag_name','Nutrient_Desc','No_of_Decimals','SR_Order']
print(data.head)
data.to_csv('Nutrients_DEF.csv',index = False)


# data = pd.read_csv('/Users/aginni/Documents/USDA_SR/Nutrients.txt',sep = '^',header = None, index_col = 0,engine = 'python')
# data.replace('^',',')
# data.columns = ['Nutrient_no','Nutrient_value','Number_data_pts','Std_err','Src_code','Deriv_code','Ref_NDB_no','Added_Nutr_mark','No_studies','Min','Max','DF','Low_EB','Up_EB','Stat_comments','Modifies_date']
# # print(data.head)
# data.to_csv('Nutrient_data.csv',index = False)


# data = pd.read_csv('/Users/aginni/Documents/USDA_SR/FOOD_DES.txt',sep = '^',header = None, engine = 'python')
# data.columns = ['NDB_no','fdgrp_code','long_desc','short_desc','common_name','Manufacturer','Survey','Ref_desc','Refuse','Sci_name','Nitrogen_factor','Protein_factor','Fat_factor','CHO_factor']
# data.replace('^',',')
# # print(data)
# data.to_csv('food_desc.csv',index = False)

# df = data.replace('^', ',')
# # df.columns = ["fdgrp_code","fdgrp_desc"]
# # print(df)
# df.to_csv('foodgroup.csv', index = False)
# Out:
# <bound method NDFrame.head of     Nutrient_no   Units      tag_name                         Nutrient_Desc  \
# 0         ~203~     ~g~      ~PROCNT~                             ~Protein~
# 1         ~204~     ~g~         ~FAT~                   ~Total lipid (fat)~
# 2         ~205~     ~g~      ~CHOCDF~         ~Carbohydrate, by difference~
# 3         ~207~     ~g~         ~ASH~                                 ~Ash~
# 4         ~208~  ~kcal~  ~ENERC_KCAL~                              ~Energy~
# 5         ~209~     ~g~      ~STARCH~                              ~Starch~
# 6         ~210~     ~g~        ~SUCS~                             ~Sucrose~
# 7         ~211~     ~g~        ~GLUS~                  ~Glucose (dextrose)~
# 8         ~212~     ~g~        ~FRUS~                            ~Fructose~
# 9         ~213~     ~g~        ~LACS~                             ~Lactose~
# 10        ~214~     ~g~        ~MALS~                             ~Maltose~
# ...
